# %% [markdown]
#                         1. Data Exploration

# %%
import pandas as pd

pd.set_option('display.max_columns', None)
# pd.set_option('display.max_rows', None)

# %%
# read data set
tree_census = pd.read_csv("Street_Tree_Census_Tree_Data.csv")
tree_census
# Out:
#         tree_id  block_id  created_at  tree_dbh  stump_diam curb_loc status  \
# 0        180683    348711  08/27/2015         3           0   OnCurb  Alive
# 1        200540    315986  09/03/2015        21           0   OnCurb  Alive
# 2        204026    218365  09/05/2015         3           0   OnCurb  Alive
# 3        204337    217969  09/05/2015        10           0   OnCurb  Alive
# 4        189565    223043  08/30/2015        21           0   OnCurb  Alive
# ...         ...       ...         ...       ...         ...      ...    ...
# 683783   155433    217978  08/18/2015        25           0   OnCurb  Alive
# 683784   183795    348185  08/29/2015         7           0   OnCurb  Alive
# 683785   166161    401670  08/22/2015        12           0   OnCurb  Alive
# 683786   184028    504204  08/29/2015         9           0   OnCurb  Alive
# 683787   200607    306527  09/03/2015        23           0   OnCurb  Alive
#
# ...

# %%
# go through with columns
tree_census.columns
# Out:
# Index(['tree_id', 'block_id', 'created_at', 'tree_dbh', 'stump_diam',
#        'curb_loc', 'status', 'health', 'spc_latin', 'spc_common', 'steward',
#        'guards', 'sidewalk', 'user_type', 'problems', 'root_stone',
#        'root_grate', 'root_other', 'trunk_wire', 'trnk_light', 'trnk_other',
#        'brch_light', 'brch_shoe', 'brch_other', 'address', 'postcode',
#        'zip_city', 'community board', 'borocode', 'borough', 'cncldist',
#        'st_assem', 'st_senate', 'nta', 'nta_name', 'boro_ct', 'state',
#        'latitude', 'longitude', 'x_sp', 'y_sp', 'council district',
#        'census tract', 'bin', 'bbl'],
#       dtype='object')

# %%
# make the subsets and used those to under stand more about the data

# %%
tree_census_subset1 = tree_census[['tree_id', 'block_id', 'created_at', 'tree_dbh', 'stump_diam',
       'curb_loc', 'status', 'health', 'spc_latin', 'spc_common']]
tree_census_subset1
# Out:
#         tree_id  block_id  created_at  tree_dbh  stump_diam curb_loc status  \
# 0        180683    348711  08/27/2015         3           0   OnCurb  Alive
# 1        200540    315986  09/03/2015        21           0   OnCurb  Alive
# 2        204026    218365  09/05/2015         3           0   OnCurb  Alive
# 3        204337    217969  09/05/2015        10           0   OnCurb  Alive
# 4        189565    223043  08/30/2015        21           0   OnCurb  Alive
# ...         ...       ...         ...       ...         ...      ...    ...
# 683783   155433    217978  08/18/2015        25           0   OnCurb  Alive
# 683784   183795    348185  08/29/2015         7           0   OnCurb  Alive
# 683785   166161    401670  08/22/2015        12           0   OnCurb  Alive
# 683786   184028    504204  08/29/2015         9           0   OnCurb  Alive
# 683787   200607    306527  09/03/2015        23           0   OnCurb  Alive
#
# ...

# %%
tree_census_subset2 = tree_census[['steward',
       'guards', 'sidewalk', 'user_type', 'problems', 'root_stone',
       'root_grate', 'root_other', 'trunk_wire', 'trnk_light', 'trnk_other',
       'brch_light', 'brch_shoe', 'brch_other']]
tree_census_subset2
# Out:
#        steward guards  sidewalk         user_type problems root_stone  \
# 0         None   None  NoDamage  TreesCount Staff     None         No
# 1         None   None    Damage  TreesCount Staff   Stones        Yes
# 2         1or2   None    Damage         Volunteer     None         No
# 3         None   None    Damage         Volunteer   Stones        Yes
# 4         None   None    Damage         Volunteer   Stones        Yes
# ...        ...    ...       ...               ...      ...        ...
# 683783    None   None    Damage         Volunteer     None         No
# 683784    1or2   None  NoDamage         Volunteer     None         No
# 683785    None   None    Damage         Volunteer     None         No
# 683786    None   None  NoDamage  TreesCount Staff     None         No
# 683787    None   None  NoDamage  TreesCount Staff     None         No
#
#        root_grate root_other trunk_wire trnk_light trnk_other brch_light  \
# ...

# %%
tree_census_subset3 = tree_census[['address', 'postcode',
       'zip_city', 'community board', 'borocode', 'borough', 'cncldist',
       'st_assem', 'st_senate', 'nta', 'nta_name', 'boro_ct', 'state',
       'latitude', 'longitude', 'x_sp', 'y_sp', 'council district',
       'census tract', 'bin', 'bbl']]
tree_census_subset3
# Out:
#                         address  postcode       zip_city  community board  \
# 0             108-005 70 AVENUE     11375   Forest Hills              406
# 1              147-074 7 AVENUE     11357     Whitestone              407
# 2             390 MORGAN AVENUE     11211       Brooklyn              301
# 3             1027 GRAND STREET     11211       Brooklyn              301
# 4                  603 6 STREET     11215       Brooklyn              306
# ...                         ...       ...            ...              ...
# 683783          32 MARCY AVENUE     11211       Brooklyn              301
# 683784  67-035 SELFRIDGE STREET     11375   Forest Hills              406
# 683785       130 BIDWELL AVENUE     10314  Staten Island              501
# 683786      1985 ANTHONY AVENUE     10457          Bronx              205
# 683787        69-069 183 STREET     11365  Fresh Meadows              408
#
#         borocode        borough  cncldist  st_assem  st_senate   nta  \
# ...

# %%
# check the null values
tree_census.isnull().sum()
# Out:
# tree_id                 0
# block_id                0
# created_at              0
# tree_dbh                0
# stump_diam              0
# curb_loc                0
# status                  0
# health              31616
# spc_latin           31619
# spc_common          31619
# steward             31615
# guards              31616
# sidewalk            31616
# user_type               0
# problems            31664
# root_stone              0
# root_grate              0
# root_other              0
# trunk_wire              0
# trnk_light              0
# trnk_other              0
# brch_light              0
# brch_shoe               0
# brch_other              0
# address                 0
# postcode                0
# zip_city                0
# community board         0
# borocode                0
# borough                 0
# cncldist                0
# st_assem                0
# st_senate               0
# nta                     0
# nta_name                0
# ...

# %%
# look those null values
tree_census[tree_census['health'].isnull()]
# Out:
#         tree_id  block_id  created_at  tree_dbh  stump_diam        curb_loc  \
# 37       211205    302080  09/09/2015         0          16          OnCurb
# 57       187807    506266  08/29/2015         0           0          OnCurb
# 196      208322    222858  09/07/2015        10           0          OnCurb
# 209      209058    415850  09/08/2015         6           0          OnCurb
# 239      203597    301947  09/04/2015         0          15          OnCurb
# ...         ...       ...         ...       ...         ...             ...
# 683693   156162    108193  08/18/2015         3           0  OffsetFromCurb
# 683695   170888    231931  08/24/2015         0           5          OnCurb
# 683697   177922    410634  08/26/2015         0          17          OnCurb
# 683698   193791    208850  09/01/2015         3           0          OnCurb
# 683699   172660    349995  08/25/2015         0           4          OnCurb
#
# ...

# %%
tree_census.describe()
# Out:
#              tree_id       block_id       tree_dbh     stump_diam  \
# count  683788.000000  683788.000000  683788.000000  683788.000000
# mean   365205.011085  313793.096236      11.279787       0.432463
# std    208122.092902  114839.024312       8.723042       3.290241
# min         3.000000  100002.000000       0.000000       0.000000
# 25%    186582.750000  221556.000000       4.000000       0.000000
# 50%    366214.500000  319967.000000       9.000000       0.000000
# 75%    546170.250000  404624.000000      16.000000       0.000000
# max    722694.000000  999999.000000     450.000000     140.000000
#
#             postcode  community board       borocode       cncldist  \
# count  683788.000000    683788.000000  683788.000000  683788.000000
# mean    10916.246044       343.505404       3.358500      29.943181
# std       651.553364       115.740601       1.166746      14.328531
# min        83.000000       101.000000       1.000000       1.000000
# ...

# %%
# explore the data types
tree_census.dtypes
# Out:
# tree_id               int64
# block_id              int64
# created_at           object
# tree_dbh              int64
# stump_diam            int64
# curb_loc             object
# status               object
# health               object
# spc_latin            object
# spc_common           object
# steward              object
# guards               object
# sidewalk             object
# user_type            object
# problems             object
# root_stone           object
# root_grate           object
# root_other           object
# trunk_wire           object
# trnk_light           object
# trnk_other           object
# brch_light           object
# brch_shoe            object
# brch_other           object
# address              object
# postcode              int64
# zip_city             object
# community board       int64
# borocode              int64
# borough              object
# cncldist              int64
# st_assem              int64
# st_senate             int64
# ...

# %%
# visulaize to understand the data insights
tree_census_subset1.hist(bins = 100, figsize = (20, 10))
# Out:
# array([[<AxesSubplot:title={'center':'tree_id'}>,
#         <AxesSubplot:title={'center':'block_id'}>],
#        [<AxesSubplot:title={'center':'tree_dbh'}>,
#         <AxesSubplot:title={'center':'stump_diam'}>]], dtype=object)

# %%
tree_census_subset1[tree_census_subset1['tree_dbh'] > 150].hist(figsize = (20, 10))
# Out:
# array([[<AxesSubplot:title={'center':'tree_id'}>,
#         <AxesSubplot:title={'center':'block_id'}>],
#        [<AxesSubplot:title={'center':'tree_dbh'}>,
#         <AxesSubplot:title={'center':'stump_diam'}>]], dtype=object)

# %%
tree_census_subset1[tree_census_subset1['tree_dbh'] > 250]
# Out:
#         tree_id  block_id  created_at  tree_dbh  stump_diam        curb_loc  \
# 2405     168583    226040  08/23/2015       425           0          OnCurb
# 29973    214534    323383  09/10/2015       282           0          OnCurb
# 83547    278078    402196  10/02/2015       255           0          OnCurb
# 180962   370606    332230  10/23/2015       389           0          OnCurb
# 187388   391542    502971  10/28/2015       291           0          OnCurb
# 201195   418433    202962  11/03/2015       318           0          OnCurb
# 227057   409369    410345  10/31/2015       298           0          OnCurb
# 228048   433258    507833  11/05/2015       450           0  OffsetFromCurb
# 270493   476317    602575  11/20/2015       318           0          OnCurb
# 346438   535083    338387  12/24/2015       261           0          OnCurb
# 439083   632254    231162  07/19/2016       266           0          OnCurb
# ...

# %%
big_trees = tree_census_subset1[tree_census_subset1['tree_dbh'] > 250]
big_trees[['tree_dbh', 'tree_id']].plot(kind = 'scatter', x = 'tree_id',y = 'tree_dbh')
# Out:
# <AxesSubplot:xlabel='tree_id', ylabel='tree_dbh'>

# %%
pd.DataFrame(tree_census['spc_latin'].value_counts()).plot(kind = 'bar', figsize = (30,15))
# Out:
# <AxesSubplot:>

# %%
tree_census.columns
# Out:
# Index(['tree_id', 'block_id', 'created_at', 'tree_dbh', 'stump_diam',
#        'curb_loc', 'status', 'health', 'spc_latin', 'spc_common', 'steward',
#        'guards', 'sidewalk', 'user_type', 'problems', 'root_stone',
#        'root_grate', 'root_other', 'trunk_wire', 'trnk_light', 'trnk_other',
#        'brch_light', 'brch_shoe', 'brch_other', 'address', 'postcode',
#        'zip_city', 'community board', 'borocode', 'borough', 'cncldist',
#        'st_assem', 'st_senate', 'nta', 'nta_name', 'boro_ct', 'state',
#        'latitude', 'longitude', 'x_sp', 'y_sp', 'council district',
#        'census tract', 'bin', 'bbl'],
#       dtype='object')

# %%
# caregorical values check
tree_census['steward'].value_counts()
# Out:
# None       487823
# 1or2       143557
# 3or4        19183
# 4orMore      1610
# Name: steward, dtype: int64

# %%
tree_census['guards'].value_counts()
# Out:
# None       572306
# Helpful     51866
# Harmful     20252
# Unsure       7748
# Name: guards, dtype: int64

# %%
tree_census['sidewalk'].value_counts()
# Out:
# NoDamage    464978
# Damage      187194
# Name: sidewalk, dtype: int64

# %%
tree_census[tree_census['status'] == 'Stump']
# Out:
#         tree_id  block_id  created_at  tree_dbh  stump_diam curb_loc status  \
# 37       211205    302080  09/09/2015         0          16   OnCurb  Stump
# 239      203597    301947  09/04/2015         0          15   OnCurb  Stump
# 641      179766    230466  08/27/2015         0          30   OnCurb  Stump
# 644      180619    348834  08/27/2015         0          10   OnCurb  Stump
# 646      208828    107238  09/08/2015         0          15   OnCurb  Stump
# ...         ...       ...         ...       ...         ...      ...    ...
# 683348   152836    217718  08/17/2015         0          13   OnCurb  Stump
# 683686   191219    321689  08/31/2015         0          25   OnCurb  Stump
# 683695   170888    231931  08/24/2015         0           5   OnCurb  Stump
# 683697   177922    410634  08/26/2015         0          17   OnCurb  Stump
# 683699   172660    349995  08/25/2015         0           4   OnCurb  Stump
#
# ...

# %%
tree_problems = tree_census[['root_stone',
       'root_grate', 'root_other', 'trunk_wire', 'trnk_light', 'trnk_other',
       'brch_light', 'brch_shoe', 'brch_other']]
tree_problems
# Out:
#        root_stone root_grate root_other trunk_wire trnk_light trnk_other  \
# 0              No         No         No         No         No         No
# 1             Yes         No         No         No         No         No
# 2              No         No         No         No         No         No
# 3             Yes         No         No         No         No         No
# 4             Yes         No         No         No         No         No
# ...           ...        ...        ...        ...        ...        ...
# 683783         No         No         No         No         No         No
# 683784         No         No         No         No         No         No
# 683785         No         No         No         No         No         No
# 683786         No         No         No         No         No         No
# 683787         No         No         No         No         No         No
#
#        brch_light brch_shoe brch_other
# 0              No        No         No
# ...

# %%
tree_problems.apply(pd.Series.value_counts)
# Out:
#      root_stone  root_grate  root_other  trunk_wire  trnk_light  trnk_other  \
# No       543789      680252      653466      670514      682757      651215
# Yes      139999        3536       30322       13274        1031       32573
#
#      brch_light  brch_shoe  brch_other
# No       621423     683377      659433
# Yes       62365        411       24355

# %% [markdown]
#                             2. Data Cleaning

# %%
mask = ((tree_census['status'] == 'stump') | (tree_census['status'] == 'Dead'))

# %%
tree_census.loc[mask].tail(50)
# Out:
#         tree_id  block_id  created_at  tree_dbh  stump_diam        curb_loc  \
# 681688   182296    104441  08/28/2015         2           0          OnCurb
# 681733   192465    104604  08/31/2015         7           0          OnCurb
# 681750   183904    504169  08/29/2015         2           0          OnCurb
# 681752   184115    504234  08/29/2015         2           0          OnCurb
# 681763   185235    505366  08/29/2015         3           0          OnCurb
# 681789   179239    409827  08/27/2015        15           0          OnCurb
# 681790   179241    409827  08/27/2015        14           0          OnCurb
# 681843   179843    216217  08/27/2015         8           0          OnCurb
# 681845   179277    229919  08/27/2015         6           0          OnCurb
# 681852   204045    415453  09/05/2015         2           0          OnCurb
# 681854   184125    504539  08/29/2015         2           0          OnCurb
# ...

# %%
# replacing Null values
after_null = tree_census.fillna("Not Applicable")

# %%
after_null.head(5)
# Out:
#    tree_id  block_id  created_at  tree_dbh  stump_diam curb_loc status health  \
# 0   180683    348711  08/27/2015         3           0   OnCurb  Alive   Fair
# 1   200540    315986  09/03/2015        21           0   OnCurb  Alive   Fair
# 2   204026    218365  09/05/2015         3           0   OnCurb  Alive   Good
# 3   204337    217969  09/05/2015        10           0   OnCurb  Alive   Good
# 4   189565    223043  08/30/2015        21           0   OnCurb  Alive   Good
#
#                             spc_latin       spc_common steward guards  \
# 0                         Acer rubrum        red maple    None   None
# 1                   Quercus palustris          pin oak    None   None
# 2  Gleditsia triacanthos var. inermis      honeylocust    1or2   None
# 3  Gleditsia triacanthos var. inermis      honeylocust    None   None
# 4                     Tilia americana  American linden    None   None
#
#    sidewalk         user_type problems root_stone root_grate root_other  \
# ...

# %%
after_mask_null.isnull().sum()
# Out:
# tree_id             0
# block_id            0
# created_at          0
# tree_dbh            0
# stump_diam          0
# curb_loc            0
# status              0
# health              0
# spc_latin           0
# spc_common          0
# steward             0
# guards              0
# sidewalk            0
# user_type           0
# problems            0
# root_stone          0
# root_grate          0
# root_other          0
# trunk_wire          0
# trnk_light          0
# trnk_other          0
# brch_light          0
# brch_shoe           0
# brch_other          0
# address             0
# postcode            0
# zip_city            0
# community board     0
# borocode            0
# borough             0
# cncldist            0
# st_assem            0
# st_senate           0
# nta                 0
# nta_name            0
# boro_ct             0
# state               0
# latitude            0
# longitude           0
# x_sp                0
# y_sp                0
# ...

# %%
pd.DataFrame(after_null['spc_latin'].value_counts())
# Out:
#                                     spc_latin
# Platanus x acerifolia                   87014
# Gleditsia triacanthos var. inermis      64264
# Pyrus calleryana                        58931
# Quercus palustris                       53185
# Acer platanoides                        34189
# ...                                       ...
# Pinus nigra                                37
# Pinus rigida                               33
# Maclura pomifera                           29
# Pinus sylvestris                           25
# Pinus virginiana                           10
#
# [133 rows x 1 columns]

# %%
# check missing values
after_null.isna().sum()
# Out:
# tree_id             0
# block_id            0
# created_at          0
# tree_dbh            0
# stump_diam          0
# curb_loc            0
# status              0
# health              0
# spc_latin           0
# spc_common          0
# steward             0
# guards              0
# sidewalk            0
# user_type           0
# problems            0
# root_stone          0
# root_grate          0
# root_other          0
# trunk_wire          0
# trnk_light          0
# trnk_other          0
# brch_light          0
# brch_shoe           0
# brch_other          0
# address             0
# postcode            0
# zip_city            0
# community board     0
# borocode            0
# borough             0
# cncldist            0
# st_assem            0
# st_senate           0
# nta                 0
# nta_name            0
# boro_ct             0
# state               0
# latitude            0
# longitude           0
# x_sp                0
# y_sp                0
# ...

# %%
# outliers
bigtrees = after_null[(after_null['tree_dbh'] > 60) | (after_null['stump_diam'] > 60)]
bigtrees
# Out:
#         tree_id  block_id  created_at  tree_dbh  stump_diam        curb_loc  \
# 2405     168583    226040  08/23/2015       425           0          OnCurb
# 4887     139665    409474  08/12/2015        72           0  OffsetFromCurb
# 6466     166008    226028  08/22/2015         0          72          OnCurb
# 6724     209349    415127  09/08/2015       122           0          OnCurb
# 7042     206818    311117  09/06/2015         0         100          OnCurb
# ...         ...       ...         ...       ...         ...             ...
# 667425   151958    330826  08/17/2015        66           0  OffsetFromCurb
# 673105   165324    206090  08/22/2015        79           0          OnCurb
# 674016   184879    504315  08/29/2015       105           0          OnCurb
# 681736   179366    349326  08/27/2015       281           0          OnCurb
# 682788   183910    505123  08/29/2015       127           0          OnCurb
#
# ...

# %%
# now find the data of which are not included with bigtrees

smalltrees = after_null[(after_null['tree_dbh'] <= 60) | (after_null['stump_diam'] <= 60)]
smalltrees
# Out:
#         tree_id  block_id  created_at  tree_dbh  stump_diam curb_loc status  \
# 0        180683    348711  08/27/2015         3           0   OnCurb  Alive
# 1        200540    315986  09/03/2015        21           0   OnCurb  Alive
# 2        204026    218365  09/05/2015         3           0   OnCurb  Alive
# 3        204337    217969  09/05/2015        10           0   OnCurb  Alive
# 4        189565    223043  08/30/2015        21           0   OnCurb  Alive
# ...         ...       ...         ...       ...         ...      ...    ...
# 683783   155433    217978  08/18/2015        25           0   OnCurb  Alive
# 683784   183795    348185  08/29/2015         7           0   OnCurb  Alive
# 683785   166161    401670  08/22/2015        12           0   OnCurb  Alive
# 683786   184028    504204  08/29/2015         9           0   OnCurb  Alive
# 683787   200607    306527  09/03/2015        23           0   OnCurb  Alive
#
# ...

# %%
# make separate dataframes where status is alive
# make separate dataframe where status is dead or stump
trees_status_alive = after_null[after_null['status'] == 'Alive']
tress_status_dead_or_stump = after_null[(after_null['status'] == 'Dead') | (after_null['status'] == 'Stump')]

# %%
# check the avg/mean or describe of the alive trees grouping by the spc_latin
trees_status_alive.groupby(by = 'spc_latin').describe()
# Out:
#                    tree_id                                                    \
#                      count           mean            std      min        25%
# spc_latin
# Acer                7080.0  473760.032486  164789.472498    373.0  401640.00
# Acer buergerianum    110.0  395036.818182  179390.324434  60373.0  276777.50
# Acer campestre      2550.0  383840.281176  184855.325418    214.0  265393.25
# Acer ginnala        2049.0  370801.015129  184408.353698   1789.0  244993.00
# Acer griseum         220.0  347632.222727  181391.826314   8643.0  178650.75
# ...                    ...            ...            ...      ...        ...
# Tsuga canadensis      88.0  268551.181818  180119.744951  16887.0  145061.75
# Ulmus americana     7975.0  308680.330533  206913.335265    123.0  120745.50
# Ulmus parvifolia    5345.0  303458.441347  188585.417734    113.0  145469.00
# Ulmus pumila        1595.0  318869.944828  203420.294281    305.0  130366.50
# ...

# %%
# final data frame
final_tree_census = smalltrees.convert_dtypes()

# %%
final_tree_census.dtypes
# Out:
# tree_id               Int64
# block_id              Int64
# created_at           string
# tree_dbh              Int64
# stump_diam            Int64
# curb_loc             string
# status               string
# health               string
# spc_latin            string
# spc_common           string
# steward              string
# guards               string
# sidewalk             string
# user_type            string
# problems             string
# root_stone           string
# root_grate           string
# root_other           string
# trunk_wire           string
# trnk_light           string
# trnk_other           string
# brch_light           string
# brch_shoe            string
# brch_other           string
# address              string
# postcode              Int64
# zip_city             string
# community board       Int64
# borocode              Int64
# borough              string
# cncldist              Int64
# st_assem              Int64
# st_senate             Int64
# ...
